# %%
from explore_sklearn_data.py import (
    generate_train_test_digits_dataset,
    grid_search_digits_data,
    visualize_dt_digits
)

# %%
X_train, X_test, y_train, y_test = generate_train_test_digits_dataset()

# %%
best_score = grid_search_digits_data(X_train, y_train)

# %%
visualize_dt_digits(
    best_estimators=best_score, 
    input_data=X_train.columns, 
    max_depth=3
)

# %%
visualize_dt_digits(
    best_estimators=best_score, 
    input_data=X_train.columns, 
    max_depth=2
)
